# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# make an API call 
#import the requests library 
import requests 

#import the API key 
from config import weather_api_key

# %%
#3) Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list- needed to then complete #4
coordinates = list(lat_lngs)

# %%
#4) Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['yumen',
#  'basco',
#  'calamar',
#  'barrow',
#  'port pirie',
#  'albany',
#  'thompson',
#  'taolanaro',
#  'havoysund',
#  'katsuura',
#  'rikitea',
#  'pallasovka',
#  'kottagudem',
#  'grindavik',
#  'avera',
#  'itarema',
#  'lunenburg',
#  'qaanaaq',
#  'lompoc',
#  'barentsburg',
#  'havelock',
#  'silifke',
#  'avarua',
#  'carnarvon',
#  'hilo',
#  'kudahuvadhoo',
#  'lavrentiya',
#  'asfi',
#  'yellowknife',
#  'ushuaia',
#  'puerto ayora',
#  'nikolskoye',
#  'butaritari',
#  'ukiah',
#  'jamestown',
#  'tsihombe',
#  'vaini',
#  'nyurba',
#  'alofi',
#  'ucluelet',
#  'severo-kurilsk',
#  'bargal',
#  'new norfolk',
#  'langfang',
#  'kodiak',
#  'yeppoon',
#  'busselton',
#  'eldoret',
#  'chemax',
#  'punta arenas',
#  'ilulissat',
#  'amderma',
#  'san quintin',
#  'bathsheba',
#  'lubango',
#  'awjilah',
#  'lerwick',
#  'tabriz',
#  'tutoia',
#  'mount gambier',
#  'tumannyy',
#  'victoria',
#  'fairbanks',
#  'geraldton',
#  'hegra',
#  'aitape',
#  'kingaroy',
#  'grand river south east',
#  'bose',
#  'iseyin',
#  'shaoguan',
#  'mao',
#  'pevek',
#  'okhotsk',
#  'emborion',
#  'port lincoln',
#  'shimoda',
#  'camana',
#  'talaja',
#  'phan thiet',
#  'loa janan',
#  'montepuez',
#  'esperance',
#  'bluff',
#  'tuatapere',
#  'shache',
#  'hermanus',
#  'bambous virieux',
#  'naze',
#  'mataura',
#  'mar del plata',
#  'fort myers beach',
#  'romitan',
#  'constitucion',
#  'sorong',
#  'te anau',
#  'safford',
#  'manturovo',
#  'monrovia',
#  'matagami',
#  'porto san giorgio',
#  'ouango',
#  'hamilton',
#  'yenagoa',
#  'bethel',
#  'belushya guba',
#  'toliary',
#  'norman wells',
#  'marrakesh',
#  'bengkulu',
#  'gravdal',
#  'castro',
#  'atuona',
#  'port elizabeth',
#  'umm lajj',
#  'hasaki',
#  'taltal',
#  'taonan',
#  'provideniya',
#  'tabiauea',
#  'lewiston',
#  'cayenne',
#  'tura',
#  'cravo norte',
#  'iracoubo',
#  'ancud',
#  'mubi',
#  'ambilobe',
#  'saint-philippe',
#  'illoqqortoormiut',
#  'narsaq',
#  'beringovskiy',
#  'faanui',
#  'saint george',
#  'hearst',
#  'boyolangu',
#  'airai',
#  'zychlin',
#  'kulhudhuffushi',
#  'cidreira',
#  'cape town',
#  'aklavik',
#  'tautira',
#  'hovd',
#  'hobart',
#  'codrington',
#  'fergus falls',
#  'sur',
#  'vanderhoof',
#  'diapaga',
#  'lebu',
#  'kibala',
#  'liancheng',
#  'beloha',
#  'karakol',
#  'north bend',
#  'mys shmidta',
#  'umzimvubu',
#  'brandon',
#  'samusu',
#  'otjiwarongo',
#  'mahebourg',
#  'urulga',
#  'urumqi',
#  'maniitsoq',
#  'nanga eboko',
#  'marawi',
#  'el alto',
#  'ponta do sol',
#  'bredasdorp',
#  'tasiilaq',
#  'rovnoye',
#  'east london',
#  'pimenta bueno',
#  'kaitangata',
#  'hami',
#  'tabulbah',
#  'homnabad',
#  'ixtapa',
#  'hithadhoo',
#  'lazaro cardenas',
#  'mitu',
#  'hobyo',
#  'pisco',
#  'saskylakh',
#  'contai',
#  'waingapu',
#  'chokurdakh',
#  'komsomolskiy',
#  'aykhal',
#  'vila velha',
#  'tuktoyaktuk',
#  'portland',
#  'terney',
#  'ranfurly',
#  'kapaa',
#  'bilibino',
#  'souillac',
#  'saleaula',
#  'zalari',
#  'dikson',
#  'progreso',
#  'alice springs',
#  'novo aripuana',
#  'mount hagen',
#  'tiksi',
#  'ngukurr',
#  'coquimbo',
#  'karratha',
#  'carmelo',
#  'dobroye',
#  'louisbourg',
#  'tigil',
#  'guerrero negro',
#  'ulladulla',
#  'impfondo',
#  'krasnoarmeysk',
#  'vila',
#  'hare bay',
#  'haines junction',
#  'taksimo',
#  'port alfred',
#  'ocampo',
#  'comodoro rivadavia',
#  'general roca',
#  'rorvik',
#  'adrar',
#  'verkhnyaya inta',
#  'ziway',
#  'umm kaddadah',
#  'thinadhoo',
#  'hanamaki',
#  'cabo san lucas',
#  'palabuhanratu',
#  'tilichiki',
#  'gewane',
#  'agua dulce',
#  'labuhan',
#  'whitehorse',
#  'castelo do piaui',
#  'arraial do cabo',
#  'kalmunai',
#  'montlucon',
#  'manokwari',
#  'port augusta',
#  'andenes',
#  'mount isa',
#  'matameye',
#  'byron bay',
#  'beisfjord',
#  'tekeli',
#  'chuy',
#  'puerto baquerizo moreno',
#  'attawapiskat',
#  'tucuman',
#  'ye',
#  'mogzon',
#  'tilbury',
#  'lumphat',
#  'krasnyy chikoy',
#  'anito',
#  'christchurch',
#  'sitka',
#  'abiy adi',
#  'urdzhar',
#  'ostrovnoy',
#  'san cristobal',
#  'kristiinankaupunki',
#  'the valley',
#  'haimen',
#  'flin flon',
#  'broken hill',
#  'tuggurt',
#  'jiroft',
#  'nanortalik',
#  'galle',
#  'san juan',
#  'paramonga',
#  'ozernovskiy',
#  'kodinsk',
#  'san patricio',
#  'miyako',
#  'saldanha',
#  'vanimo',
#  'upernavik',
#  'high level',
#  'fez',
#  'sao jose da coroa grande',
#  'kerteh',
#  'challans',
#  'flinders',
#  'makat',
#  'srednekolymsk',
#  'namibe',
#  'penzance',
#  'saint anthony',
#  'longyearbyen',
#  'babanusah',
#  'buraydah',
#  'half moon bay',
#  'iskateley',
#  'khatanga',
#  'nsanje',
#  'kavaratti',
#  'firozpur',
#  'cao bang',
#  'mujiayingzi',
#  'taoudenni',
#  'kahului',
#  'barawe',
#  'meulaboh',
#  'oksovskiy',
#  'nhulunbuy',
#  'kavieng',
#  'vaitape',
#  'jalu',
#  'xichang',
#  'nantucket',
#  'meadow lake',
#  'raudeberg',
#  'mwinilunga',
#  'ban nahin',
#  'torbay',
#  'nautla',
#  'sibolga',
#  'naftah',
#  'warren',
#  'ascension',
#  'samalaeulu',
#  'yar-sale',
#  'sambava',
#  'varhaug',
#  'york',
#  'felanitx',
#  'georgetown',
#  'kuche',
#  'leningradskiy',
#  'tezu',
#  'vaitupu',
#  'leninskoye',
#  'maloshuyka',
#  'ribeira grande',
#  'raton',
#  'shiyan',
#  'polyarnyy',
#  'lac du bonnet',
#  'grand gaube',
#  'civitavecchia',
#  'okha',
#  'mizan teferi',
#  'aksarka',
#  'presidencia roque saenz pena',
#  'ocumare del tuy',
#  'kirakira',
#  'araouane',
#  'meyungs',
#  'west bay',
#  'opuwo',
#  'nizhneyansk',
#  'hay river',
#  'mayo',
#  'ahipara',
#  'saint-francois',
#  'san andres',
#  'bandar-e torkaman',
#  'vostok',
#  'udachnyy',
#  'mackay',
#  'victoria point',
#  'carutapera',
#  'mocambique',
#  'maine-soroa',
#  'kununurra',
#  'asbury park',
#  'lunino',
#  'kuching',
#  'mentok',
#  'galesong',
#  'husavik',
#  'lorengau',
#  'maykor',
#  'bluefield',
#  'laguna',
#  'camacha',
#  'hinton',
#  'qingdao',
#  'vallenar',
#  'real',
#  'warburton',
#  'marcona',
#  'saint-georges',
#  'uinskoye',
#  'cerqueira cesar',
#  'quatre cocos',
#  'djougou',
#  'klamath falls',
#  'sabzevar',
#  'tottori',
#  'marovoay',
#  'reftinskiy',
#  'bhadrapur',
#  'riyadh',
#  'coatzintla',
#  'raga',
#  'cururupu',
#  'vidim',
#  'ponta delgada',
#  'conde',
#  'yuli',
#  'petropavlovsk-kamchatskiy',
#  'khonuu',
#  'saquena',
#  'dulmen',
#  'pastavy',
#  'malwan',
#  'ocozocoautla',
#  'morondava',
#  'kupang',
#  'wladyslawowo',
#  'hualmay',
#  'namatanai',
#  'port-gentil',
#  'bowen',
#  'salalah',
#  'saint-joseph',
#  'black river',
#  'krasnoselkup',
#  'soyo',
#  'lianran',
#  'general cepeda',
#  'berlevag',
#  'khani',
#  'valle hermoso',
#  'chipinge',
#  'farafangana',
#  'fortuna',
#  'lolua',
#  'urcos',
#  'swan river',
#  'san ramon',
#  'broome',
#  'awbari',
#  'buala',
#  'poso',
#  'klaksvik',
#  'iqaluit',
#  'dudinka',
#  'yarkovo',
#  'tabas',
#  'saint-pierre',
#  'zhanaozen',
#  'palmer',
#  'guozhen',
#  'kruisfontein',
#  'peniche',
#  'huarmey',
#  'marystown',
#  'tugolesskiy bor',
#  'rio gallegos',
#  'lufilufi',
#  'manuk mangkaw',
#  'pilna',
#  'martil',
#  'mandalgovi',
#  'serenje',
#  'port macquarie',
#  'seoul',
#  'touros',
#  'anadyr',
#  'zambezi',
#  'henties bay',
#  'port hardy',
#  'kita',
#  'coihaique',
#  'burica',
#  'porto torres',
#  'monywa',
#  'pula',
#  'valparaiso',
#  'puerto escondido',
#  'bafra',
#  'olafsvik',
#  'beyneu',
#  'saint-augustin',
#  'lamu',
#  'arua',
#  'darhan',
#  'talnakh',
#  'ushtobe',
#  'samarai',
#  'bezhetsk',
#  'kenai',
#  'madanapalle',
#  'trincomalee',
#  'chumikan',
#  'enumclaw',
#  'miri',
#  'bonham',
#  'gazli',
#  'tallahassee',
#  'tarakan',
#  'rocha',
#  'paamiut',
#  'sao joao da barra',
#  'nusaybin',
#  'rungata',
#  'sao filipe',
#  'sharan',
#  'maarianhamina',
#  'clyde river',
#  'burgeo',
#  'shakawe',
#  'marmaron',
#  'dolbeau',
#  'evensk',
#  'kozlovka',
#  'urengoy',
#  'bull savanna',
#  'dingle',
#  'roxas',
#  'vargem alta',
#  'cap malheureux',
#  'hambantota',
#  'bouna',
#  'podporozhye',
#  'bubaque',
#  'xadani',
#  'lagoa',
#  'hanna',
#  'coos bay',
#  'belaya gora',
#  'mombetsu',
#  'uyuni',
#  'vawkavysk',
#  'ust-kamchatsk',
#  'ambon',
#  'mahibadhoo',
#  'verkh-usugli',
#  'guadalupe victoria',
#  'port blair',
#  'wucheng',
#  'yunjinghong',
#  'saint albans',
#  'aras',
#  'sept-iles',
#  'warqla',
#  'kurumkan',
#  'praxedis guerrero',
#  'sibu',
#  'caohe',
#  'rawson',
#  'kysyl-syr',
#  'merauke',
#  'luebo',
#  'male',
#  'fatikchhari',
#  'korla',
#  'waw',
#  'santa rosa',
#  'almazar',
#  'zaragoza',
#  'turangi',
#  'mbini',
#  'tiznit',
#  'najran',
#  'gat',
#  'nome',
#  'inongo',
#  'svetlogorsk',
#  'sogdiondon',
#  'kamenskoye',
#  'strezhevoy',
#  'koumac',
#  'pringsewu',
#  'mahadday weyne',
#  'cockburn town',
#  'grimari',
#  'yulara',
#  'lasa',
#  'barabai',
#  'bangassou',
#  'tessalit',
#  'maghama',
#  'isangel',
#  'ballina',
#  'breves',
#  'ayer itam',
#  'cherskiy',
#  'malazgirt',
#  'mizusawa',
#  'prince rupert',
#  'donskoy',
#  'la primavera',
#  'novouzensk',
#  'labutta',
#  'gurgan',
#  'kokorevka',
#  'shelburne',
#  'gillette',
#  'kuryk',
#  'slavsk',
#  'spassk',
#  'mayor pablo lagerenza',
#  'nijar',
#  'wuzhou',
#  'pierre',
#  'baykit',
#  'belogorsk',
#  'hoquiam',
#  'maumere',
#  'amapa',
#  'plettenberg bay',
#  'lucapa',
#  'tshane',
#  'mocuba',
#  'hirara',
#  'saint-louis',
#  'tullahoma',
#  'tonantins',
#  'denau',
#  'yerbogachen',
#  'mecca',
#  'tabuk',
#  'patiya',
#  'plouzane',
#  'bonthe',
#  'bud',
#  'jinchang',
#  'rosarito',
#  'frankfurt',
#  'karauzyak',
#  'xingyi',
#  'werda',
#  'lakes entrance',
#  'ampanihy',
#  'come',
#  'rawannawi',
#  'leiyang',
#  'baykalsk',
#  'sao gabriel da cachoeira',
#  'shu',
#  'ca mau',
#  'bojnurd',
#  'la ronge',
#  'marshall',
#  'qaqortoq',
#  'hirson',
#  'yabelo',
#  'golkoy',
#  'kalabo',
#  'nara',
#  'marienburg',
#  'atbasar',
#  'le creusot',
#  'fort-shevchenko',
#  'santa isabel do rio negro',
#  'peshkovo',
#  'zabol',
#  'iralaya',
#  'vardo',
#  'poum',
#  'pasni',
#  'mandan',
#  'mastung',
#  'at-bashi',
#  'luneville',
#  'qandala',
#  'denpasar',
#  'pavlovka',
#  'wilmington island',
#  'joensuu',
#  'aloleng',
#  'agucadoura',
#  'bogorodskoye',
#  'itoman',
#  'moron',
#  'salto',
#  'curup',
#  'el retorno',
#  'tumut',
#  'harrisonburg',
#  'gao',
#  'sentyabrskiy',
#  'glendive',
#  'toledo',
#  'chambersburg',
#  'tepalcingo',
#  'alice town',
#  'abu dhabi',
#  'houma',
#  'goba',
#  'arman',
#  'los llanos de aridane',
#  'nalut',
#  'kemijarvi',
#  'kismayo',
#  'nisia floresta',
#  'smiltene',
#  'limpapa',
#  'kloulklubed',
#  'teahupoo',
#  'omboue',
#  'pathein',
#  'gunjur',
#  'sisimiut',
#  'miles city',
#  'pangnirtung',
#  'phrai bung',
#  'obama',
#  'champerico',
#  'prainha',
#  'bolobo',
#  'abu kamal',
#  'agadir',
#  'qinhuangdao',
#  'santa cruz',
#  'muroto',
#  'huejuquilla el alto',
#  'banda aceh',
#  'bodden town',
#  'kapit',
#  'sooke',
#  'khilok',
#  'itaituba',
#  'douentza',
#  'launceston',
#  'ocos',
#  'darfield',
#  'asyut',
#  'axim',
#  'payo',
#  'marquette',
#  'bahia blanca',
#  'minjur',
#  'silver city',
#  'makakilo city',
#  'porto nacional',
#  'omsukchan',
#  'tahoua',
#  'diffa',
#  'cabedelo',
#  'vao',
#  'ambulu',
#  'poshekhonye',
#  'sorvag',
#  'sistranda',
#  'birjand',
#  'anjangaon',
#  'coracao de jesus',
#  'sinnamary',
#  'pundaguitan',
#  'egvekinot',
#  'daly city',
#  'maracaibo',
#  'timmins',
#  'dwarka',
#  'songea',
#  'ho chi minh city',
#  'karamken',
#  'iwanai',
#  'baoshan',
#  'harper',
#  'abu samrah',
#  'luis correia',
#  'albi',
#  'chaiyaphum',
#  'sangin']

# %%
#5) starting URL for Weather Map API Call 
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cfe3856151850da13b3a9c6ee190d3ac

# %%
#6.2.6 1- create an empty list to hold the weather data 
city_data=[]
#print the beginning of the loggins 
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters 
record_count=1
set_count=1

#6.2.6 2-loop through all the cities inout list 
for i, city in enumerate(cities):
    
    #goup cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count = 1
        time.sleep(60)
    
    #create an endpoint URL with each city 
    city_url=url+"&q="+ city.replace(" ", "+")
    
    #log the URL, record, and set numbers and the city 
    print(f"Processing Record {record_count} of Set {set_count}| {city}")
    #add 1 to the record count 
    record_count+=1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1| yumen
# Processing Record 2 of Set 1| basco
# Processing Record 3 of Set 1| calamar
# Processing Record 4 of Set 1| barrow
# Processing Record 5 of Set 1| port pirie
# Processing Record 6 of Set 1| albany
# Processing Record 7 of Set 1| thompson
# Processing Record 8 of Set 1| taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1| havoysund
# Processing Record 10 of Set 1| katsuura
# Processing Record 11 of Set 1| rikitea
# Processing Record 12 of Set 1| pallasovka
# Processing Record 13 of Set 1| kottagudem
# Processing Record 14 of Set 1| grindavik
# Processing Record 15 of Set 1| avera
# Processing Record 16 of Set 1| itarema
# Processing Record 17 of Set 1| lunenburg
# Processing Record 18 of Set 1| qaanaaq
# Processing Record 19 of Set 1| lompoc
# Processing Record 20 of Set 1| barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1| havelock
# Processing Record 22 of Set 1| silifke
# Processing Record 23 of Set 1| avarua
# Processing Record 24 of Set 1| carnarvon
# Processing Record 25 of Set 1| hilo
# Processing Record 26 of Set 1| kudahuvadhoo
# Processing Record 27 of Set 1| lavrentiya
# Processing Record 28 of Set 1| asfi
# Processing Record 29 of Set 1| yellowknife
# Processing Record 30 of Set 1| ushuaia
# Processing Record 31 of Set 1| puerto ayora
# Processing Record 32 of Set 1| nikolskoye
# Processing Record 33 of Set 1| butaritari
# Processing Record 34 of Set 1| ukiah
# Processing Record 35 of Set 1| jamestown
# Processing Record 36 of Set 1| tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1| vaini
# Processing Record 38 of Set 1| nyurba
# Processing Record 39 of Set 1| alofi
# Processing Record 40 of Set 1| ucluelet
# Processing Record 41 of Set 1| severo-kurilsk
# Processing Record 42 of Set 1| bargal
# City not found. Skipping...
# Processing Record 43 of Set 1| new norfolk
# Processing Record 44 of Set 1| langfang
# Processing Record 45 of Set 1| kodiak
# Processing Record 46 of Set 1| yeppoon
# Processing Record 47 of Set 1| busselton
# Processing Record 48 of Set 1| eldoret
# Processing Record 49 of Set 1| chemax
# Processing Record 50 of Set 1| punta arenas
# Processing Record 1 of Set 2| ilulissat
# Processing Record 2 of Set 2| amderma
# City not found. Skipping...
# Processing Record 3 of Set 2| san quintin
# Processing Record 4 of Set 2| bathsheba
# Processing Record 5 of Set 2| lubango
# Processing Record 6 of Set 2| awjilah
# Processing Record 7 of Set 2| lerwick
# Processing Record 8 of Set 2| tabriz
# Processing Record 9 of Set 2| tutoia
# Processing Record 10 of Set 2| mount gambier
# Processing Record 11 of Set 2| tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 2| victoria
# Processing Record 13 of Set 2| fairbanks
# Processing Record 14 of Set 2| geraldton
# Processing Record 15 of Set 2| hegra
# Processing Record 16 of Set 2| aitape
# Processing Record 17 of Set 2| kingaroy
# Processing Record 18 of Set 2| grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 2| bose
# Processing Record 20 of Set 2| iseyin
# Processing Record 21 of Set 2| shaoguan
# Processing Record 22 of Set 2| mao
# Processing Record 23 of Set 2| pevek
# Processing Record 24 of Set 2| okhotsk
# Processing Record 25 of Set 2| emborion
# Processing Record 26 of Set 2| port lincoln
# Processing Record 27 of Set 2| shimoda
# Processing Record 28 of Set 2| camana
# Processing Record 29 of Set 2| talaja
# Processing Record 30 of Set 2| phan thiet
# Processing Record 31 of Set 2| loa janan
# Processing Record 32 of Set 2| montepuez
# Processing Record 33 of Set 2| esperance
# Processing Record 34 of Set 2| bluff
# Processing Record 35 of Set 2| tuatapere
# Processing Record 36 of Set 2| shache
# Processing Record 37 of Set 2| hermanus
# Processing Record 38 of Set 2| bambous virieux
# Processing Record 39 of Set 2| naze
# Processing Record 40 of Set 2| mataura
# Processing Record 41 of Set 2| mar del plata
# Processing Record 42 of Set 2| fort myers beach
# Processing Record 43 of Set 2| romitan
# Processing Record 44 of Set 2| constitucion
# Processing Record 45 of Set 2| sorong
# Processing Record 46 of Set 2| te anau
# Processing Record 47 of Set 2| safford
# Processing Record 48 of Set 2| manturovo
# Processing Record 49 of Set 2| monrovia
# Processing Record 50 of Set 2| matagami
# Processing Record 1 of Set 3| porto san giorgio
# Processing Record 2 of Set 3| ouango
# Processing Record 3 of Set 3| hamilton
# Processing Record 4 of Set 3| yenagoa
# Processing Record 5 of Set 3| bethel
# Processing Record 6 of Set 3| belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3| toliary
# City not found. Skipping...
# Processing Record 8 of Set 3| norman wells
# Processing Record 9 of Set 3| marrakesh
# Processing Record 10 of Set 3| bengkulu
# Processing Record 11 of Set 3| gravdal
# Processing Record 12 of Set 3| castro
# Processing Record 13 of Set 3| atuona
# Processing Record 14 of Set 3| port elizabeth
# Processing Record 15 of Set 3| umm lajj
# Processing Record 16 of Set 3| hasaki
# Processing Record 17 of Set 3| taltal
# Processing Record 18 of Set 3| taonan
# Processing Record 19 of Set 3| provideniya
# Processing Record 20 of Set 3| tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 3| lewiston
# Processing Record 22 of Set 3| cayenne
# Processing Record 23 of Set 3| tura
# Processing Record 24 of Set 3| cravo norte
# Processing Record 25 of Set 3| iracoubo
# Processing Record 26 of Set 3| ancud
# Processing Record 27 of Set 3| mubi
# Processing Record 28 of Set 3| ambilobe
# Processing Record 29 of Set 3| saint-philippe
# Processing Record 30 of Set 3| illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3| narsaq
# Processing Record 32 of Set 3| beringovskiy
# Processing Record 33 of Set 3| faanui
# Processing Record 34 of Set 3| saint george
# Processing Record 35 of Set 3| hearst
# Processing Record 36 of Set 3| boyolangu
# Processing Record 37 of Set 3| airai
# Processing Record 38 of Set 3| zychlin
# Processing Record 39 of Set 3| kulhudhuffushi
# Processing Record 40 of Set 3| cidreira
# Processing Record 41 of Set 3| cape town
# Processing Record 42 of Set 3| aklavik
# Processing Record 43 of Set 3| tautira
# Processing Record 44 of Set 3| hovd
# Processing Record 45 of Set 3| hobart
# Processing Record 46 of Set 3| codrington
# Processing Record 47 of Set 3| fergus falls
# Processing Record 48 of Set 3| sur
# Processing Record 49 of Set 3| vanderhoof
# Processing Record 50 of Set 3| diapaga
# Processing Record 1 of Set 4| lebu
# Processing Record 2 of Set 4| kibala
# Processing Record 3 of Set 4| liancheng
# Processing Record 4 of Set 4| beloha
# Processing Record 5 of Set 4| karakol
# Processing Record 6 of Set 4| north bend
# Processing Record 7 of Set 4| mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 4| umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 4| brandon
# Processing Record 10 of Set 4| samusu
# City not found. Skipping...
# Processing Record 11 of Set 4| otjiwarongo
# Processing Record 12 of Set 4| mahebourg
# Processing Record 13 of Set 4| urulga
# City not found. Skipping...
# Processing Record 14 of Set 4| urumqi
# Processing Record 15 of Set 4| maniitsoq
# Processing Record 16 of Set 4| nanga eboko
# Processing Record 17 of Set 4| marawi
# Processing Record 18 of Set 4| el alto
# Processing Record 19 of Set 4| ponta do sol
# Processing Record 20 of Set 4| bredasdorp
# Processing Record 21 of Set 4| tasiilaq
# Processing Record 22 of Set 4| rovnoye
# Processing Record 23 of Set 4| east london
# Processing Record 24 of Set 4| pimenta bueno
# Processing Record 25 of Set 4| kaitangata
# Processing Record 26 of Set 4| hami
# Processing Record 27 of Set 4| tabulbah
# City not found. Skipping...
# Processing Record 28 of Set 4| homnabad
# Processing Record 29 of Set 4| ixtapa
# Processing Record 30 of Set 4| hithadhoo
# Processing Record 31 of Set 4| lazaro cardenas
# Processing Record 32 of Set 4| mitu
# Processing Record 33 of Set 4| hobyo
# Processing Record 34 of Set 4| pisco
# Processing Record 35 of Set 4| saskylakh
# Processing Record 36 of Set 4| contai
# Processing Record 37 of Set 4| waingapu
# Processing Record 38 of Set 4| chokurdakh
# Processing Record 39 of Set 4| komsomolskiy
# Processing Record 40 of Set 4| aykhal
# Processing Record 41 of Set 4| vila velha
# Processing Record 42 of Set 4| tuktoyaktuk
# Processing Record 43 of Set 4| portland
# Processing Record 44 of Set 4| terney
# Processing Record 45 of Set 4| ranfurly
# Processing Record 46 of Set 4| kapaa
# Processing Record 47 of Set 4| bilibino
# Processing Record 48 of Set 4| souillac
# Processing Record 49 of Set 4| saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4| zalari
# Processing Record 1 of Set 5| dikson
# Processing Record 2 of Set 5| progreso
# Processing Record 3 of Set 5| alice springs
# Processing Record 4 of Set 5| novo aripuana
# Processing Record 5 of Set 5| mount hagen
# Processing Record 6 of Set 5| tiksi
# Processing Record 7 of Set 5| ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 5| coquimbo
# Processing Record 9 of Set 5| karratha
# Processing Record 10 of Set 5| carmelo
# Processing Record 11 of Set 5| dobroye
# Processing Record 12 of Set 5| louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 5| tigil
# Processing Record 14 of Set 5| guerrero negro
# Processing Record 15 of Set 5| ulladulla
# Processing Record 16 of Set 5| impfondo
# Processing Record 17 of Set 5| krasnoarmeysk
# Processing Record 18 of Set 5| vila
# Processing Record 19 of Set 5| hare bay
# Processing Record 20 of Set 5| haines junction
# Processing Record 21 of Set 5| taksimo
# Processing Record 22 of Set 5| port alfred
# Processing Record 23 of Set 5| ocampo
# Processing Record 24 of Set 5| comodoro rivadavia
# Processing Record 25 of Set 5| general roca
# Processing Record 26 of Set 5| rorvik
# Processing Record 27 of Set 5| adrar
# Processing Record 28 of Set 5| verkhnyaya inta
# Processing Record 29 of Set 5| ziway
# Processing Record 30 of Set 5| umm kaddadah
# Processing Record 31 of Set 5| thinadhoo
# Processing Record 32 of Set 5| hanamaki
# Processing Record 33 of Set 5| cabo san lucas
# Processing Record 34 of Set 5| palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 5| tilichiki
# Processing Record 36 of Set 5| gewane
# Processing Record 37 of Set 5| agua dulce
# Processing Record 38 of Set 5| labuhan
# Processing Record 39 of Set 5| whitehorse
# Processing Record 40 of Set 5| castelo do piaui
# Processing Record 41 of Set 5| arraial do cabo
# Processing Record 42 of Set 5| kalmunai
# Processing Record 43 of Set 5| montlucon
# Processing Record 44 of Set 5| manokwari
# Processing Record 45 of Set 5| port augusta
# Processing Record 46 of Set 5| andenes
# Processing Record 47 of Set 5| mount isa
# Processing Record 48 of Set 5| matameye
# City not found. Skipping...
# Processing Record 49 of Set 5| byron bay
# Processing Record 50 of Set 5| beisfjord
# Processing Record 1 of Set 6| tekeli
# Processing Record 2 of Set 6| chuy
# Processing Record 3 of Set 6| puerto baquerizo moreno
# Processing Record 4 of Set 6| attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 6| tucuman
# Processing Record 6 of Set 6| ye
# City not found. Skipping...
# Processing Record 7 of Set 6| mogzon
# Processing Record 8 of Set 6| tilbury
# Processing Record 9 of Set 6| lumphat
# Processing Record 10 of Set 6| krasnyy chikoy
# Processing Record 11 of Set 6| anito
# Processing Record 12 of Set 6| christchurch
# Processing Record 13 of Set 6| sitka
# Processing Record 14 of Set 6| abiy adi
# City not found. Skipping...
# Processing Record 15 of Set 6| urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 6| ostrovnoy
# Processing Record 17 of Set 6| san cristobal
# Processing Record 18 of Set 6| kristiinankaupunki
# Processing Record 19 of Set 6| the valley
# Processing Record 20 of Set 6| haimen
# Processing Record 21 of Set 6| flin flon
# Processing Record 22 of Set 6| broken hill
# Processing Record 23 of Set 6| tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 6| jiroft
# City not found. Skipping...
# Processing Record 25 of Set 6| nanortalik
# Processing Record 26 of Set 6| galle
# Processing Record 27 of Set 6| san juan
# Processing Record 28 of Set 6| paramonga
# Processing Record 29 of Set 6| ozernovskiy
# Processing Record 30 of Set 6| kodinsk
# Processing Record 31 of Set 6| san patricio
# Processing Record 32 of Set 6| miyako
# Processing Record 33 of Set 6| saldanha
# Processing Record 34 of Set 6| vanimo
# Processing Record 35 of Set 6| upernavik
# Processing Record 36 of Set 6| high level
# Processing Record 37 of Set 6| fez
# Processing Record 38 of Set 6| sao jose da coroa grande
# Processing Record 39 of Set 6| kerteh
# City not found. Skipping...
# Processing Record 40 of Set 6| challans
# Processing Record 41 of Set 6| flinders
# Processing Record 42 of Set 6| makat
# Processing Record 43 of Set 6| srednekolymsk
# Processing Record 44 of Set 6| namibe
# Processing Record 45 of Set 6| penzance
# Processing Record 46 of Set 6| saint anthony
# Processing Record 47 of Set 6| longyearbyen
# Processing Record 48 of Set 6| babanusah
# City not found. Skipping...
# Processing Record 49 of Set 6| buraydah
# Processing Record 50 of Set 6| half moon bay
# Processing Record 1 of Set 7| iskateley
# Processing Record 2 of Set 7| khatanga
# Processing Record 3 of Set 7| nsanje
# Processing Record 4 of Set 7| kavaratti
# Processing Record 5 of Set 7| firozpur
# Processing Record 6 of Set 7| cao bang
# Processing Record 7 of Set 7| mujiayingzi
# Processing Record 8 of Set 7| taoudenni
# Processing Record 9 of Set 7| kahului
# Processing Record 10 of Set 7| barawe
# City not found. Skipping...
# Processing Record 11 of Set 7| meulaboh
# Processing Record 12 of Set 7| oksovskiy
# Processing Record 13 of Set 7| nhulunbuy
# Processing Record 14 of Set 7| kavieng
# Processing Record 15 of Set 7| vaitape
# Processing Record 16 of Set 7| jalu
# Processing Record 17 of Set 7| xichang
# Processing Record 18 of Set 7| nantucket
# Processing Record 19 of Set 7| meadow lake
# Processing Record 20 of Set 7| raudeberg
# Processing Record 21 of Set 7| mwinilunga
# Processing Record 22 of Set 7| ban nahin
# Processing Record 23 of Set 7| torbay
# Processing Record 24 of Set 7| nautla
# Processing Record 25 of Set 7| sibolga
# Processing Record 26 of Set 7| naftah
# City not found. Skipping...
# Processing Record 27 of Set 7| warren
# Processing Record 28 of Set 7| ascension
# Processing Record 29 of Set 7| samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 7| yar-sale
# Processing Record 31 of Set 7| sambava
# Processing Record 32 of Set 7| varhaug
# Processing Record 33 of Set 7| york
# Processing Record 34 of Set 7| felanitx
# Processing Record 35 of Set 7| georgetown
# Processing Record 36 of Set 7| kuche
# City not found. Skipping...
# Processing Record 37 of Set 7| leningradskiy
# Processing Record 38 of Set 7| tezu
# Processing Record 39 of Set 7| vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 7| leninskoye
# Processing Record 41 of Set 7| maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 7| ribeira grande
# Processing Record 43 of Set 7| raton
# Processing Record 44 of Set 7| shiyan
# Processing Record 45 of Set 7| polyarnyy
# Processing Record 46 of Set 7| lac du bonnet
# Processing Record 47 of Set 7| grand gaube
# Processing Record 48 of Set 7| civitavecchia
# Processing Record 49 of Set 7| okha
# Processing Record 50 of Set 7| mizan teferi
# Processing Record 1 of Set 8| aksarka
# Processing Record 2 of Set 8| presidencia roque saenz pena
# Processing Record 3 of Set 8| ocumare del tuy
# Processing Record 4 of Set 8| kirakira
# Processing Record 5 of Set 8| araouane
# Processing Record 6 of Set 8| meyungs
# City not found. Skipping...
# Processing Record 7 of Set 8| west bay
# Processing Record 8 of Set 8| opuwo
# Processing Record 9 of Set 8| nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 8| hay river
# Processing Record 11 of Set 8| mayo
# Processing Record 12 of Set 8| ahipara
# Processing Record 13 of Set 8| saint-francois
# Processing Record 14 of Set 8| san andres
# Processing Record 15 of Set 8| bandar-e torkaman
# City not found. Skipping...
# Processing Record 16 of Set 8| vostok
# Processing Record 17 of Set 8| udachnyy
# Processing Record 18 of Set 8| mackay
# Processing Record 19 of Set 8| victoria point
# Processing Record 20 of Set 8| carutapera
# Processing Record 21 of Set 8| mocambique
# City not found. Skipping...
# Processing Record 22 of Set 8| maine-soroa
# Processing Record 23 of Set 8| kununurra
# Processing Record 24 of Set 8| asbury park
# Processing Record 25 of Set 8| lunino
# Processing Record 26 of Set 8| kuching
# Processing Record 27 of Set 8| mentok
# City not found. Skipping...
# Processing Record 28 of Set 8| galesong
# Processing Record 29 of Set 8| husavik
# Processing Record 30 of Set 8| lorengau
# Processing Record 31 of Set 8| maykor
# Processing Record 32 of Set 8| bluefield
# Processing Record 33 of Set 8| laguna
# Processing Record 34 of Set 8| camacha
# Processing Record 35 of Set 8| hinton
# Processing Record 36 of Set 8| qingdao
# Processing Record 37 of Set 8| vallenar
# Processing Record 38 of Set 8| real
# Processing Record 39 of Set 8| warburton
# Processing Record 40 of Set 8| marcona
# City not found. Skipping...
# Processing Record 41 of Set 8| saint-georges
# Processing Record 42 of Set 8| uinskoye
# Processing Record 43 of Set 8| cerqueira cesar
# Processing Record 44 of Set 8| quatre cocos
# Processing Record 45 of Set 8| djougou
# Processing Record 46 of Set 8| klamath falls
# Processing Record 47 of Set 8| sabzevar
# Processing Record 48 of Set 8| tottori
# Processing Record 49 of Set 8| marovoay
# Processing Record 50 of Set 8| reftinskiy
# Processing Record 1 of Set 9| bhadrapur
# Processing Record 2 of Set 9| riyadh
# Processing Record 3 of Set 9| coatzintla
# Processing Record 4 of Set 9| raga
# Processing Record 5 of Set 9| cururupu
# Processing Record 6 of Set 9| vidim
# Processing Record 7 of Set 9| ponta delgada
# Processing Record 8 of Set 9| conde
# Processing Record 9 of Set 9| yuli
# Processing Record 10 of Set 9| petropavlovsk-kamchatskiy
# Processing Record 11 of Set 9| khonuu
# City not found. Skipping...
# Processing Record 12 of Set 9| saquena
# Processing Record 13 of Set 9| dulmen
# Processing Record 14 of Set 9| pastavy
# Processing Record 15 of Set 9| malwan
# City not found. Skipping...
# Processing Record 16 of Set 9| ocozocoautla
# City not found. Skipping...
# Processing Record 17 of Set 9| morondava
# Processing Record 18 of Set 9| kupang
# Processing Record 19 of Set 9| wladyslawowo
# Processing Record 20 of Set 9| hualmay
# Processing Record 21 of Set 9| namatanai
# Processing Record 22 of Set 9| port-gentil
# Processing Record 23 of Set 9| bowen
# Processing Record 24 of Set 9| salalah
# Processing Record 25 of Set 9| saint-joseph
# Processing Record 26 of Set 9| black river
# Processing Record 27 of Set 9| krasnoselkup
# Processing Record 28 of Set 9| soyo
# Processing Record 29 of Set 9| lianran
# Processing Record 30 of Set 9| general cepeda
# Processing Record 31 of Set 9| berlevag
# Processing Record 32 of Set 9| khani
# Processing Record 33 of Set 9| valle hermoso
# Processing Record 34 of Set 9| chipinge
# Processing Record 35 of Set 9| farafangana
# Processing Record 36 of Set 9| fortuna
# Processing Record 37 of Set 9| lolua
# City not found. Skipping...
# Processing Record 38 of Set 9| urcos
# Processing Record 39 of Set 9| swan river
# Processing Record 40 of Set 9| san ramon
# Processing Record 41 of Set 9| broome
# Processing Record 42 of Set 9| awbari
# Processing Record 43 of Set 9| buala
# Processing Record 44 of Set 9| poso
# Processing Record 45 of Set 9| klaksvik
# Processing Record 46 of Set 9| iqaluit
# Processing Record 47 of Set 9| dudinka
# Processing Record 48 of Set 9| yarkovo
# Processing Record 49 of Set 9| tabas
# Processing Record 50 of Set 9| saint-pierre
# Processing Record 1 of Set 10| zhanaozen
# Processing Record 2 of Set 10| palmer
# Processing Record 3 of Set 10| guozhen
# Processing Record 4 of Set 10| kruisfontein
# Processing Record 5 of Set 10| peniche
# Processing Record 6 of Set 10| huarmey
# Processing Record 7 of Set 10| marystown
# Processing Record 8 of Set 10| tugolesskiy bor
# Processing Record 9 of Set 10| rio gallegos
# Processing Record 10 of Set 10| lufilufi
# Processing Record 11 of Set 10| manuk mangkaw
# Processing Record 12 of Set 10| pilna
# Processing Record 13 of Set 10| martil
# Processing Record 14 of Set 10| mandalgovi
# Processing Record 15 of Set 10| serenje
# Processing Record 16 of Set 10| port macquarie
# Processing Record 17 of Set 10| seoul
# Processing Record 18 of Set 10| touros
# Processing Record 19 of Set 10| anadyr
# Processing Record 20 of Set 10| zambezi
# Processing Record 21 of Set 10| henties bay
# Processing Record 22 of Set 10| port hardy
# Processing Record 23 of Set 10| kita
# Processing Record 24 of Set 10| coihaique
# Processing Record 25 of Set 10| burica
# City not found. Skipping...
# Processing Record 26 of Set 10| porto torres
# Processing Record 27 of Set 10| monywa
# Processing Record 28 of Set 10| pula
# Processing Record 29 of Set 10| valparaiso
# Processing Record 30 of Set 10| puerto escondido
# Processing Record 31 of Set 10| bafra
# Processing Record 32 of Set 10| olafsvik
# Processing Record 33 of Set 10| beyneu
# Processing Record 34 of Set 10| saint-augustin
# Processing Record 35 of Set 10| lamu
# Processing Record 36 of Set 10| arua
# Processing Record 37 of Set 10| darhan
# Processing Record 38 of Set 10| talnakh
# Processing Record 39 of Set 10| ushtobe
# Processing Record 40 of Set 10| samarai
# Processing Record 41 of Set 10| bezhetsk
# Processing Record 42 of Set 10| kenai
# Processing Record 43 of Set 10| madanapalle
# Processing Record 44 of Set 10| trincomalee
# Processing Record 45 of Set 10| chumikan
# Processing Record 46 of Set 10| enumclaw
# Processing Record 47 of Set 10| miri
# Processing Record 48 of Set 10| bonham
# Processing Record 49 of Set 10| gazli
# Processing Record 50 of Set 10| tallahassee
# Processing Record 1 of Set 11| tarakan
# Processing Record 2 of Set 11| rocha
# Processing Record 3 of Set 11| paamiut
# Processing Record 4 of Set 11| sao joao da barra
# Processing Record 5 of Set 11| nusaybin
# Processing Record 6 of Set 11| rungata
# City not found. Skipping...
# Processing Record 7 of Set 11| sao filipe
# Processing Record 8 of Set 11| sharan
# Processing Record 9 of Set 11| maarianhamina
# Processing Record 10 of Set 11| clyde river
# Processing Record 11 of Set 11| burgeo
# Processing Record 12 of Set 11| shakawe
# Processing Record 13 of Set 11| marmaron
# City not found. Skipping...
# Processing Record 14 of Set 11| dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 11| evensk
# Processing Record 16 of Set 11| kozlovka
# Processing Record 17 of Set 11| urengoy
# Processing Record 18 of Set 11| bull savanna
# Processing Record 19 of Set 11| dingle
# Processing Record 20 of Set 11| roxas
# Processing Record 21 of Set 11| vargem alta
# Processing Record 22 of Set 11| cap malheureux
# Processing Record 23 of Set 11| hambantota
# Processing Record 24 of Set 11| bouna
# Processing Record 25 of Set 11| podporozhye
# Processing Record 26 of Set 11| bubaque
# Processing Record 27 of Set 11| xadani
# City not found. Skipping...
# Processing Record 28 of Set 11| lagoa
# Processing Record 29 of Set 11| hanna
# Processing Record 30 of Set 11| coos bay
# Processing Record 31 of Set 11| belaya gora
# Processing Record 32 of Set 11| mombetsu
# Processing Record 33 of Set 11| uyuni
# Processing Record 34 of Set 11| vawkavysk
# Processing Record 35 of Set 11| ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 11| ambon
# Processing Record 37 of Set 11| mahibadhoo
# Processing Record 38 of Set 11| verkh-usugli
# Processing Record 39 of Set 11| guadalupe victoria
# Processing Record 40 of Set 11| port blair
# Processing Record 41 of Set 11| wucheng
# Processing Record 42 of Set 11| yunjinghong
# City not found. Skipping...
# Processing Record 43 of Set 11| saint albans
# Processing Record 44 of Set 11| aras
# Processing Record 45 of Set 11| sept-iles
# Processing Record 46 of Set 11| warqla
# City not found. Skipping...
# Processing Record 47 of Set 11| kurumkan
# Processing Record 48 of Set 11| praxedis guerrero
# Processing Record 49 of Set 11| sibu
# Processing Record 50 of Set 11| caohe
# Processing Record 1 of Set 12| rawson
# Processing Record 2 of Set 12| kysyl-syr
# Processing Record 3 of Set 12| merauke
# Processing Record 4 of Set 12| luebo
# Processing Record 5 of Set 12| male
# Processing Record 6 of Set 12| fatikchhari
# City not found. Skipping...
# Processing Record 7 of Set 12| korla
# Processing Record 8 of Set 12| waw
# Processing Record 9 of Set 12| santa rosa
# Processing Record 10 of Set 12| almazar
# Processing Record 11 of Set 12| zaragoza
# Processing Record 12 of Set 12| turangi
# Processing Record 13 of Set 12| mbini
# Processing Record 14 of Set 12| tiznit
# Processing Record 15 of Set 12| najran
# Processing Record 16 of Set 12| gat
# Processing Record 17 of Set 12| nome
# Processing Record 18 of Set 12| inongo
# Processing Record 19 of Set 12| svetlogorsk
# Processing Record 20 of Set 12| sogdiondon
# City not found. Skipping...
# Processing Record 21 of Set 12| kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 12| strezhevoy
# Processing Record 23 of Set 12| koumac
# Processing Record 24 of Set 12| pringsewu
# Processing Record 25 of Set 12| mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 12| cockburn town
# Processing Record 27 of Set 12| grimari
# City not found. Skipping...
# Processing Record 28 of Set 12| yulara
# Processing Record 29 of Set 12| lasa
# Processing Record 30 of Set 12| barabai
# Processing Record 31 of Set 12| bangassou
# Processing Record 32 of Set 12| tessalit
# Processing Record 33 of Set 12| maghama
# City not found. Skipping...
# Processing Record 34 of Set 12| isangel
# Processing Record 35 of Set 12| ballina
# Processing Record 36 of Set 12| breves
# Processing Record 37 of Set 12| ayer itam
# City not found. Skipping...
# Processing Record 38 of Set 12| cherskiy
# Processing Record 39 of Set 12| malazgirt
# Processing Record 40 of Set 12| mizusawa
# Processing Record 41 of Set 12| prince rupert
# Processing Record 42 of Set 12| donskoy
# Processing Record 43 of Set 12| la primavera
# Processing Record 44 of Set 12| novouzensk
# Processing Record 45 of Set 12| labutta
# City not found. Skipping...
# Processing Record 46 of Set 12| gurgan
# City not found. Skipping...
# Processing Record 47 of Set 12| kokorevka
# Processing Record 48 of Set 12| shelburne
# Processing Record 49 of Set 12| gillette
# Processing Record 50 of Set 12| kuryk
# Processing Record 1 of Set 13| slavsk
# Processing Record 2 of Set 13| spassk
# Processing Record 3 of Set 13| mayor pablo lagerenza
# Processing Record 4 of Set 13| nijar
# Processing Record 5 of Set 13| wuzhou
# Processing Record 6 of Set 13| pierre
# Processing Record 7 of Set 13| baykit
# Processing Record 8 of Set 13| belogorsk
# Processing Record 9 of Set 13| hoquiam
# Processing Record 10 of Set 13| maumere
# Processing Record 11 of Set 13| amapa
# Processing Record 12 of Set 13| plettenberg bay
# Processing Record 13 of Set 13| lucapa
# Processing Record 14 of Set 13| tshane
# Processing Record 15 of Set 13| mocuba
# Processing Record 16 of Set 13| hirara
# Processing Record 17 of Set 13| saint-louis
# Processing Record 18 of Set 13| tullahoma
# Processing Record 19 of Set 13| tonantins
# Processing Record 20 of Set 13| denau
# City not found. Skipping...
# Processing Record 21 of Set 13| yerbogachen
# Processing Record 22 of Set 13| mecca
# Processing Record 23 of Set 13| tabuk
# Processing Record 24 of Set 13| patiya
# Processing Record 25 of Set 13| plouzane
# Processing Record 26 of Set 13| bonthe
# Processing Record 27 of Set 13| bud
# Processing Record 28 of Set 13| jinchang
# Processing Record 29 of Set 13| rosarito
# Processing Record 30 of Set 13| frankfurt
# Processing Record 31 of Set 13| karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 13| xingyi
# Processing Record 33 of Set 13| werda
# Processing Record 34 of Set 13| lakes entrance
# Processing Record 35 of Set 13| ampanihy
# Processing Record 36 of Set 13| come
# Processing Record 37 of Set 13| rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 13| leiyang
# Processing Record 39 of Set 13| baykalsk
# Processing Record 40 of Set 13| sao gabriel da cachoeira
# Processing Record 41 of Set 13| shu
# Processing Record 42 of Set 13| ca mau
# Processing Record 43 of Set 13| bojnurd
# Processing Record 44 of Set 13| la ronge
# Processing Record 45 of Set 13| marshall
# Processing Record 46 of Set 13| qaqortoq
# Processing Record 47 of Set 13| hirson
# Processing Record 48 of Set 13| yabelo
# Processing Record 49 of Set 13| golkoy
# Processing Record 50 of Set 13| kalabo
# Processing Record 1 of Set 14| nara
# Processing Record 2 of Set 14| marienburg
# Processing Record 3 of Set 14| atbasar
# Processing Record 4 of Set 14| le creusot
# Processing Record 5 of Set 14| fort-shevchenko
# Processing Record 6 of Set 14| santa isabel do rio negro
# Processing Record 7 of Set 14| peshkovo
# Processing Record 8 of Set 14| zabol
# Processing Record 9 of Set 14| iralaya
# Processing Record 10 of Set 14| vardo
# Processing Record 11 of Set 14| poum
# Processing Record 12 of Set 14| pasni
# Processing Record 13 of Set 14| mandan
# Processing Record 14 of Set 14| mastung
# Processing Record 15 of Set 14| at-bashi
# Processing Record 16 of Set 14| luneville
# Processing Record 17 of Set 14| qandala
# Processing Record 18 of Set 14| denpasar
# Processing Record 19 of Set 14| pavlovka
# Processing Record 20 of Set 14| wilmington island
# Processing Record 21 of Set 14| joensuu
# Processing Record 22 of Set 14| aloleng
# Processing Record 23 of Set 14| agucadoura
# Processing Record 24 of Set 14| bogorodskoye
# Processing Record 25 of Set 14| itoman
# Processing Record 26 of Set 14| moron
# Processing Record 27 of Set 14| salto
# Processing Record 28 of Set 14| curup
# Processing Record 29 of Set 14| el retorno
# Processing Record 30 of Set 14| tumut
# Processing Record 31 of Set 14| harrisonburg
# Processing Record 32 of Set 14| gao
# Processing Record 33 of Set 14| sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 14| glendive
# Processing Record 35 of Set 14| toledo
# Processing Record 36 of Set 14| chambersburg
# Processing Record 37 of Set 14| tepalcingo
# Processing Record 38 of Set 14| alice town
# Processing Record 39 of Set 14| abu dhabi
# Processing Record 40 of Set 14| houma
# Processing Record 41 of Set 14| goba
# Processing Record 42 of Set 14| arman
# Processing Record 43 of Set 14| los llanos de aridane
# Processing Record 44 of Set 14| nalut
# Processing Record 45 of Set 14| kemijarvi
# Processing Record 46 of Set 14| kismayo
# Processing Record 47 of Set 14| nisia floresta
# Processing Record 48 of Set 14| smiltene
# Processing Record 49 of Set 14| limpapa
# Processing Record 50 of Set 14| kloulklubed
# Processing Record 1 of Set 15| teahupoo
# Processing Record 2 of Set 15| omboue
# Processing Record 3 of Set 15| pathein
# Processing Record 4 of Set 15| gunjur
# Processing Record 5 of Set 15| sisimiut
# Processing Record 6 of Set 15| miles city
# Processing Record 7 of Set 15| pangnirtung
# Processing Record 8 of Set 15| phrai bung
# City not found. Skipping...
# Processing Record 9 of Set 15| obama
# Processing Record 10 of Set 15| champerico
# Processing Record 11 of Set 15| prainha
# Processing Record 12 of Set 15| bolobo
# Processing Record 13 of Set 15| abu kamal
# Processing Record 14 of Set 15| agadir
# Processing Record 15 of Set 15| qinhuangdao
# Processing Record 16 of Set 15| santa cruz
# Processing Record 17 of Set 15| muroto
# Processing Record 18 of Set 15| huejuquilla el alto
# Processing Record 19 of Set 15| banda aceh
# Processing Record 20 of Set 15| bodden town
# Processing Record 21 of Set 15| kapit
# Processing Record 22 of Set 15| sooke
# Processing Record 23 of Set 15| khilok
# Processing Record 24 of Set 15| itaituba
# Processing Record 25 of Set 15| douentza
# Processing Record 26 of Set 15| launceston
# Processing Record 27 of Set 15| ocos
# Processing Record 28 of Set 15| darfield
# Processing Record 29 of Set 15| asyut
# Processing Record 30 of Set 15| axim
# Processing Record 31 of Set 15| payo
# Processing Record 32 of Set 15| marquette
# Processing Record 33 of Set 15| bahia blanca
# Processing Record 34 of Set 15| minjur
# Processing Record 35 of Set 15| silver city
# Processing Record 36 of Set 15| makakilo city
# Processing Record 37 of Set 15| porto nacional
# Processing Record 38 of Set 15| omsukchan
# Processing Record 39 of Set 15| tahoua
# Processing Record 40 of Set 15| diffa
# Processing Record 41 of Set 15| cabedelo
# Processing Record 42 of Set 15| vao
# Processing Record 43 of Set 15| ambulu
# Processing Record 44 of Set 15| poshekhonye
# Processing Record 45 of Set 15| sorvag
# City not found. Skipping...
# Processing Record 46 of Set 15| sistranda
# Processing Record 47 of Set 15| birjand
# Processing Record 48 of Set 15| anjangaon
# Processing Record 49 of Set 15| coracao de jesus
# Processing Record 50 of Set 15| sinnamary
# Processing Record 1 of Set 16| pundaguitan
# Processing Record 2 of Set 16| egvekinot
# Processing Record 3 of Set 16| daly city
# Processing Record 4 of Set 16| maracaibo
# Processing Record 5 of Set 16| timmins
# Processing Record 6 of Set 16| dwarka
# Processing Record 7 of Set 16| songea
# Processing Record 8 of Set 16| ho chi minh city
# Processing Record 9 of Set 16| karamken
# City not found. Skipping...
# Processing Record 10 of Set 16| iwanai
# Processing Record 11 of Set 16| baoshan
# Processing Record 12 of Set 16| harper
# Processing Record 13 of Set 16| abu samrah
# Processing Record 14 of Set 16| luis correia
# Processing Record 15 of Set 16| albi
# Processing Record 16 of Set 16| chaiyaphum
# Processing Record 17 of Set 16| sangin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Yumen  40.2833   97.2000     19.38        38           0       15.26
# 1       Basco  20.4487  121.9702     75.81        68          63       23.49
# 2     Calamar  10.2511  -74.9146     80.55        65          94       11.61
# 3      Barrow  71.2906 -156.7887    -12.98        77           1       13.80
# 4  Port Pirie -33.1833  138.0167     66.29        68          10       11.07
# 5      Albany  42.6001  -73.9662     41.52        41           0        8.30
# 6    Thompson  55.7435  -97.8558     -1.84       100          95        2.04
# 7   Havoysund  70.9963   24.6622     32.88        98         100       10.89
# 8    Katsuura  35.1333  140.3000     50.18        65          76       14.67
# 9     Rikitea -23.1203 -134.9692     77.31        77          87        9.42
#
#   Country
# 0      CN
# 1      PH
# 2      CO
# 3      US
# 4      AU
# 5      US
# 6      CA
# 7      NO
# 8      JP
# 9      PF

# %%
#rearange column order 
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Yumen      CN  40.2833   97.2000     19.38        38           0
# 1       Basco      PH  20.4487  121.9702     75.81        68          63
# 2     Calamar      CO  10.2511  -74.9146     80.55        65          94
# 3      Barrow      US  71.2906 -156.7887    -12.98        77           1
# 4  Port Pirie      AU -33.1833  138.0167     66.29        68          10
# 5      Albany      US  42.6001  -73.9662     41.52        41           0
# 6    Thompson      CA  55.7435  -97.8558     -1.84       100          95
# 7   Havoysund      NO  70.9963   24.6622     32.88        98         100
# 8    Katsuura      JP  35.1333  140.3000     50.18        65          76
# 9     Rikitea      PF -23.1203 -134.9692     77.31        77          87
#
#    Wind Speed
# 0       15.26
# 1       23.49
# 2       11.61
# 3       13.80
# 4       11.07
# 5        8.30
# 6        2.04
# 7       10.89
# 8       14.67
# 9        9.42

# %%
#create the output file (CSV)
output_data_file="Weather_Database/WeatherPy_Database.csv"
#export the city_data into a CSV
city_data_df.to_csv(output_data_file,index_label="City_ID")
#the index label part will add a header in the CSV file to column A or the index
