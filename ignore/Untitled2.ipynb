# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# make an API call 
#import the requests library 
import requests 

#import the API key 
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#3) Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list- needed to then complete #4
coordinates = list(lat_lngs)

# %%
#4) Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
#5) starting URL for Weather Map API Call 
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cfe3856151850da13b3a9c6ee190d3ac

# %%
#6.2.6 1- create an empty list to hold the weather data 
city_data=[]
#print the beginning of the loggins 
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters 
record_count=1
set_count=1

#6.2.6 2-loop through all the cities inout list 
for i, city in enumerate(cities):
    
    #goup cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count = 1
        time.sleep(60)
    
    #create an endpoint URL with each city 
    city_url=url+"&q="+ city.replace(" ", "+")
    
    #log the URL, record, and set numbers and the city 
    print(f"Processing Record {record_count} of Set {set_count}| {city}")
    #add 1 to the record count 
    record_count+=1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1| codrington
# Processing Record 2 of Set 1| provideniya
# Processing Record 3 of Set 1| tasiilaq
# Processing Record 4 of Set 1| ribeira grande
# Processing Record 5 of Set 1| alofi
# Processing Record 6 of Set 1| sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1| busselton
# Processing Record 8 of Set 1| avera
# Processing Record 9 of Set 1| yumen
# Processing Record 10 of Set 1| salina
# Processing Record 11 of Set 1| hobyo
# Processing Record 12 of Set 1| bluff
# Processing Record 13 of Set 1| nikolskoye
# Processing Record 14 of Set 1| olden
# Processing Record 15 of Set 1| tarabuco
# Processing Record 16 of Set 1| punta arenas
# Processing Record 17 of Set 1| appenzell
# Processing Record 18 of Set 1| bredasdorp
# Processing Record 19 of Set 1| nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1| mahebourg
# Processing Record 21 of Set 1| xai-xai
# Processing Record 22 of Set 1| kapaa
# Processing Record 23 of Set 1| port blair
# Processing Record 24 of Set 1| suleja
# Processing Record 25 of Set 1| sinkat
# City not found. Skipping...
# Processing Record 26 of Set 1| tamiahua
# Processing Record 27 of Set 1| guerrero negro
# Processing Record 28 of Set 1| kjollefjord
# Processing Record 29 of Set 1| qaanaaq
# Processing Record 30 of Set 1| rikitea
# Processing Record 31 of Set 1| egvekinot
# Processing Record 32 of Set 1| dikson
# Processing Record 33 of Set 1| severo-yeniseyskiy
# Processing Record 34 of Set 1| meulaboh
# Processing Record 35 of Set 1| ostrovnoy
# Processing Record 36 of Set 1| arraial do cabo
# Processing Record 37 of Set 1| shimoda
# Processing Record 38 of Set 1| fairbanks
# Processing Record 39 of Set 1| zaraza
# Processing Record 40 of Set 1| yellowknife
# Processing Record 41 of Set 1| barrow
# Processing Record 42 of Set 1| yulara
# Processing Record 43 of Set 1| oksfjord
# Processing Record 44 of Set 1| albany
# Processing Record 45 of Set 1| broome
# Processing Record 46 of Set 1| tibati
# Processing Record 47 of Set 1| hermanus
# Processing Record 48 of Set 1| neuquen
# Processing Record 49 of Set 1| atuona
# Processing Record 50 of Set 1| ranong
# Processing Record 1 of Set 2| kodiak
# Processing Record 2 of Set 2| duz
# City not found. Skipping...
# Processing Record 3 of Set 2| talnakh
# Processing Record 4 of Set 2| nguiu
# City not found. Skipping...
# Processing Record 5 of Set 2| shihezi
# Processing Record 6 of Set 2| formosa do rio preto
# Processing Record 7 of Set 2| vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2| logan lake
# Processing Record 9 of Set 2| lorengau
# Processing Record 10 of Set 2| santa paula
# Processing Record 11 of Set 2| georgetown
# Processing Record 12 of Set 2| castro
# Processing Record 13 of Set 2| ushuaia
# Processing Record 14 of Set 2| new norfolk
# Processing Record 15 of Set 2| saint-philippe
# Processing Record 16 of Set 2| puerto ayora
# Processing Record 17 of Set 2| san patricio
# Processing Record 18 of Set 2| landang
# City not found. Skipping...
# Processing Record 19 of Set 2| boguchany
# Processing Record 20 of Set 2| taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2| te anau
# Processing Record 22 of Set 2| fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 2| bethel
# Processing Record 24 of Set 2| rawson
# Processing Record 25 of Set 2| cape town
# Processing Record 26 of Set 2| vila
# Processing Record 27 of Set 2| mpika
# Processing Record 28 of Set 2| longyearbyen
# Processing Record 29 of Set 2| grand gaube
# Processing Record 30 of Set 2| ancud
# Processing Record 31 of Set 2| vaini
# Processing Record 32 of Set 2| kulhudhuffushi
# Processing Record 33 of Set 2| hithadhoo
# Processing Record 34 of Set 2| bathsheba
# Processing Record 35 of Set 2| clyde river
# Processing Record 36 of Set 2| awbari
# Processing Record 37 of Set 2| kaitangata
# Processing Record 38 of Set 2| avarua
# Processing Record 39 of Set 2| skibbereen
# Processing Record 40 of Set 2| nishihara
# Processing Record 41 of Set 2| kavieng
# Processing Record 42 of Set 2| sovetskiy
# Processing Record 43 of Set 2| riyadh
# Processing Record 44 of Set 2| santa vitoria do palmar
# Processing Record 45 of Set 2| kruisfontein
# Processing Record 46 of Set 2| karratha
# Processing Record 47 of Set 2| olafsvik
# Processing Record 48 of Set 2| tuktoyaktuk
# Processing Record 49 of Set 2| kaeo
# Processing Record 50 of Set 2| hobart
# Processing Record 1 of Set 3| poum
# Processing Record 2 of Set 3| port alfred
# Processing Record 3 of Set 3| takayama
# Processing Record 4 of Set 3| pozo colorado
# Processing Record 5 of Set 3| port elizabeth
# Processing Record 6 of Set 3| canazas
# Processing Record 7 of Set 3| salalah
# Processing Record 8 of Set 3| sao joao da barra
# Processing Record 9 of Set 3| butaritari
# Processing Record 10 of Set 3| ronne
# Processing Record 11 of Set 3| bonavista
# Processing Record 12 of Set 3| airai
# Processing Record 13 of Set 3| cabedelo
# Processing Record 14 of Set 3| nong bua
# Processing Record 15 of Set 3| bambous virieux
# Processing Record 16 of Set 3| diego de almagro
# Processing Record 17 of Set 3| soest
# Processing Record 18 of Set 3| souillac
# Processing Record 19 of Set 3| nizhniy kuranakh
# Processing Record 20 of Set 3| batemans bay
# Processing Record 21 of Set 3| tual
# Processing Record 22 of Set 3| zwedru
# Processing Record 23 of Set 3| antalaha
# Processing Record 24 of Set 3| jamestown
# Processing Record 25 of Set 3| formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 3| waipawa
# Processing Record 27 of Set 3| vila franca do campo
# Processing Record 28 of Set 3| ponta do sol
# Processing Record 29 of Set 3| navirai
# Processing Record 30 of Set 3| khatanga
# Processing Record 31 of Set 3| vanimo
# Processing Record 32 of Set 3| hasaki
# Processing Record 33 of Set 3| reo
# Processing Record 34 of Set 3| east london
# Processing Record 35 of Set 3| labateca
# Processing Record 36 of Set 3| hilo
# Processing Record 37 of Set 3| grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3| tailai
# Processing Record 39 of Set 3| bafoulabe
# Processing Record 40 of Set 3| qianan
# Processing Record 41 of Set 3| sao filipe
# Processing Record 42 of Set 3| puerto baquerizo moreno
# Processing Record 43 of Set 3| torbay
# Processing Record 44 of Set 3| marystown
# Processing Record 45 of Set 3| mar del plata
# Processing Record 46 of Set 3| faanui
# Processing Record 47 of Set 3| iqaluit
# Processing Record 48 of Set 3| reyes
# Processing Record 49 of Set 3| fukue
# Processing Record 50 of Set 3| alice town
# Processing Record 1 of Set 4| papara
# Processing Record 2 of Set 4| oranjemund
# Processing Record 3 of Set 4| ahuimanu
# Processing Record 4 of Set 4| arandas
# Processing Record 5 of Set 4| bazaliya
# Processing Record 6 of Set 4| mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 4| belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4| kamenka
# Processing Record 9 of Set 4| zeya
# Processing Record 10 of Set 4| illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 4| mataura
# Processing Record 12 of Set 4| ornskoldsvik
# Processing Record 13 of Set 4| conde
# Processing Record 14 of Set 4| lebu
# Processing Record 15 of Set 4| thompson
# Processing Record 16 of Set 4| toamasina
# Processing Record 17 of Set 4| bajo baudo
# City not found. Skipping...
# Processing Record 18 of Set 4| saldanha
# Processing Record 19 of Set 4| kushnarenkovo
# Processing Record 20 of Set 4| banda aceh
# Processing Record 21 of Set 4| bagdarin
# Processing Record 22 of Set 4| qiqihar
# Processing Record 23 of Set 4| marsabit
# Processing Record 24 of Set 4| niono
# Processing Record 25 of Set 4| biskamzha
# Processing Record 26 of Set 4| chumikan
# Processing Record 27 of Set 4| marsh harbour
# Processing Record 28 of Set 4| high level
# Processing Record 29 of Set 4| okhotsk
# Processing Record 30 of Set 4| sataua
# City not found. Skipping...
# Processing Record 31 of Set 4| phatthalung
# Processing Record 32 of Set 4| sao jose de ribamar
# Processing Record 33 of Set 4| komsomolskiy
# Processing Record 34 of Set 4| upernavik
# Processing Record 35 of Set 4| ridgecrest
# Processing Record 36 of Set 4| srednekolymsk
# Processing Record 37 of Set 4| lavrentiya
# Processing Record 38 of Set 4| nanakuli
# Processing Record 39 of Set 4| tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 4| concarneau
# Processing Record 41 of Set 4| mushie
# Processing Record 42 of Set 4| tuatapere
# Processing Record 43 of Set 4| broken hill
# Processing Record 44 of Set 4| bima
# Processing Record 45 of Set 4| chunskiy
# Processing Record 46 of Set 4| xining
# Processing Record 47 of Set 4| olinda
# Processing Record 48 of Set 4| starosubkhangulovo
# Processing Record 49 of Set 4| abu dhabi
# Processing Record 50 of Set 4| ilinskiy
# Processing Record 1 of Set 5| pangnirtung
# Processing Record 2 of Set 5| bayji
# Processing Record 3 of Set 5| tumpat
# Processing Record 4 of Set 5| samusu
# City not found. Skipping...
# Processing Record 5 of Set 5| mutsamudu
# City not found. Skipping...
# Processing Record 6 of Set 5| andernach
# Processing Record 7 of Set 5| barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5| luan
# Processing Record 9 of Set 5| lianran
# Processing Record 10 of Set 5| santa barbara
# Processing Record 11 of Set 5| tshikapa
# Processing Record 12 of Set 5| ilulissat
# Processing Record 13 of Set 5| kyren
# Processing Record 14 of Set 5| neiafu
# Processing Record 15 of Set 5| stabat
# Processing Record 16 of Set 5| fort-shevchenko
# Processing Record 17 of Set 5| togur
# Processing Record 18 of Set 5| malkapur
# Processing Record 19 of Set 5| teshie
# Processing Record 20 of Set 5| harper
# Processing Record 21 of Set 5| chokurdakh
# Processing Record 22 of Set 5| oussouye
# Processing Record 23 of Set 5| dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 5| almaznyy
# Processing Record 25 of Set 5| aranos
# Processing Record 26 of Set 5| kaitong
# Processing Record 27 of Set 5| stryn
# Processing Record 28 of Set 5| bage
# Processing Record 29 of Set 5| severo-kurilsk
# Processing Record 30 of Set 5| anchorage
# Processing Record 31 of Set 5| ambon
# Processing Record 32 of Set 5| port lincoln
# Processing Record 33 of Set 5| luderitz
# Processing Record 34 of Set 5| saint george
# Processing Record 35 of Set 5| tekax
# City not found. Skipping...
# Processing Record 36 of Set 5| saleaula
# City not found. Skipping...
# Processing Record 37 of Set 5| auki
# Processing Record 38 of Set 5| vanavara
# Processing Record 39 of Set 5| bereda
# Processing Record 40 of Set 5| harnosand
# Processing Record 41 of Set 5| attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5| lata
# Processing Record 43 of Set 5| preeceville
# Processing Record 44 of Set 5| lompoc
# Processing Record 45 of Set 5| fallon
# Processing Record 46 of Set 5| cap malheureux
# Processing Record 47 of Set 5| pevek
# Processing Record 48 of Set 5| aktau
# Processing Record 49 of Set 5| mafeteng
# Processing Record 50 of Set 5| marcona
# City not found. Skipping...
# Processing Record 1 of Set 6| flinders
# Processing Record 2 of Set 6| los llanos de aridane
# Processing Record 3 of Set 6| fortuna
# Processing Record 4 of Set 6| jacareacanga
# Processing Record 5 of Set 6| kuche
# City not found. Skipping...
# Processing Record 6 of Set 6| kununurra
# Processing Record 7 of Set 6| katsuura
# Processing Record 8 of Set 6| louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 6| laguna
# Processing Record 10 of Set 6| waycross
# Processing Record 11 of Set 6| viligili
# City not found. Skipping...
# Processing Record 12 of Set 6| san jose
# Processing Record 13 of Set 6| klaksvik
# Processing Record 14 of Set 6| makakilo city
# Processing Record 15 of Set 6| la palma
# Processing Record 16 of Set 6| samarai
# Processing Record 17 of Set 6| meyungs
# City not found. Skipping...
# Processing Record 18 of Set 6| kalemie
# Processing Record 19 of Set 6| nanortalik
# Processing Record 20 of Set 6| copiapo
# Processing Record 21 of Set 6| la pintada
# Processing Record 22 of Set 6| victoria
# Processing Record 23 of Set 6| rionero in vulture
# Processing Record 24 of Set 6| lumphat
# Processing Record 25 of Set 6| strezhevoy
# Processing Record 26 of Set 6| skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 6| banjar
# Processing Record 28 of Set 6| saskylakh
# Processing Record 29 of Set 6| aripuana
# Processing Record 30 of Set 6| wanaka
# Processing Record 31 of Set 6| half moon bay
# Processing Record 32 of Set 6| ettaiyapuram
# Processing Record 33 of Set 6| sitka
# Processing Record 34 of Set 6| tadine
# Processing Record 35 of Set 6| adrar
# Processing Record 36 of Set 6| grindavik
# Processing Record 37 of Set 6| riachao das neves
# Processing Record 38 of Set 6| port macquarie
# Processing Record 39 of Set 6| voh
# Processing Record 40 of Set 6| tiksi
# Processing Record 41 of Set 6| selenduma
# Processing Record 42 of Set 6| santa rosa
# Processing Record 43 of Set 6| tartagal
# Processing Record 44 of Set 6| nova olimpia
# Processing Record 45 of Set 6| ierapetra
# Processing Record 46 of Set 6| dryden
# Processing Record 47 of Set 6| san juan
# Processing Record 48 of Set 6| alugan
# Processing Record 49 of Set 6| bushehr
# Processing Record 50 of Set 6| atagay
# Processing Record 1 of Set 7| ust-kuyga
# Processing Record 2 of Set 7| ciras
# City not found. Skipping...
# Processing Record 3 of Set 7| yar-sale
# Processing Record 4 of Set 7| cururupu
# Processing Record 5 of Set 7| beyneu
# Processing Record 6 of Set 7| mayahi
# Processing Record 7 of Set 7| murgab
# Processing Record 8 of Set 7| seddon
# Processing Record 9 of Set 7| mandalgovi
# Processing Record 10 of Set 7| shache
# Processing Record 11 of Set 7| mao
# Processing Record 12 of Set 7| college
# Processing Record 13 of Set 7| norman wells
# Processing Record 14 of Set 7| hay river
# Processing Record 15 of Set 7| dustlik
# Processing Record 16 of Set 7| calama
# Processing Record 17 of Set 7| buenavista
# Processing Record 18 of Set 7| tilichiki
# Processing Record 19 of Set 7| constitucion
# Processing Record 20 of Set 7| tezu
# Processing Record 21 of Set 7| saiha
# Processing Record 22 of Set 7| moerai
# Processing Record 23 of Set 7| kushima
# Processing Record 24 of Set 7| mimongo
# Processing Record 25 of Set 7| takoradi
# Processing Record 26 of Set 7| yermakovskoye
# Processing Record 27 of Set 7| ostersund
# Processing Record 28 of Set 7| carnarvon
# Processing Record 29 of Set 7| victor harbor
# Processing Record 30 of Set 7| havre-saint-pierre
# Processing Record 31 of Set 7| hamilton
# Processing Record 32 of Set 7| pimentel
# Processing Record 33 of Set 7| inuvik
# Processing Record 34 of Set 7| bandarbeyla
# Processing Record 35 of Set 7| peachland
# Processing Record 36 of Set 7| nuuk
# Processing Record 37 of Set 7| new kensington
# Processing Record 38 of Set 7| bosaso
# Processing Record 39 of Set 7| novyy oskol
# Processing Record 40 of Set 7| acarau
# Processing Record 41 of Set 7| beringovskiy
# Processing Record 42 of Set 7| lasa
# Processing Record 43 of Set 7| praia
# Processing Record 44 of Set 7| amderma
# City not found. Skipping...
# Processing Record 45 of Set 7| mount isa
# Processing Record 46 of Set 7| cherskiy
# Processing Record 47 of Set 7| nome
# Processing Record 48 of Set 7| salekhard
# Processing Record 49 of Set 7| daru
# Processing Record 50 of Set 7| lolua
# City not found. Skipping...
# Processing Record 1 of Set 8| arlit
# Processing Record 2 of Set 8| chunoyar
# Processing Record 3 of Set 8| danielskuil
# Processing Record 4 of Set 8| kijang
# Processing Record 5 of Set 8| sibolga
# Processing Record 6 of Set 8| padang
# Processing Record 7 of Set 8| verkhoyansk
# Processing Record 8 of Set 8| omboue
# Processing Record 9 of Set 8| moshi
# Processing Record 10 of Set 8| vila velha
# Processing Record 11 of Set 8| saint-louis
# Processing Record 12 of Set 8| tolaga bay
# Processing Record 13 of Set 8| deer lake
# Processing Record 14 of Set 8| risor
# Processing Record 15 of Set 8| ingham
# Processing Record 16 of Set 8| hobe sound
# Processing Record 17 of Set 8| roald
# Processing Record 18 of Set 8| vilyuysk
# Processing Record 19 of Set 8| pachino
# Processing Record 20 of Set 8| katobu
# Processing Record 21 of Set 8| verkhnetulomskiy
# Processing Record 22 of Set 8| changji
# Processing Record 23 of Set 8| talakan
# Processing Record 24 of Set 8| honningsvag
# Processing Record 25 of Set 8| kirakira
# Processing Record 26 of Set 8| salym
# Processing Record 27 of Set 8| rio gallegos
# Processing Record 28 of Set 8| zhaozhou
# Processing Record 29 of Set 8| vikindu
# Processing Record 30 of Set 8| bilma
# Processing Record 31 of Set 8| dwarka
# Processing Record 32 of Set 8| chaklasi
# Processing Record 33 of Set 8| zhangye
# Processing Record 34 of Set 8| zhigansk
# Processing Record 35 of Set 8| gazanjyk
# Processing Record 36 of Set 8| angoram
# Processing Record 37 of Set 8| cabo san lucas
# Processing Record 38 of Set 8| martapura
# Processing Record 39 of Set 8| santa maria
# Processing Record 40 of Set 8| saint-georges
# Processing Record 41 of Set 8| bela vista do paraiso
# Processing Record 42 of Set 8| baykit
# Processing Record 43 of Set 8| port said
# Processing Record 44 of Set 8| sedelnikovo
# City not found. Skipping...
# Processing Record 45 of Set 8| solsvik
# City not found. Skipping...
# Processing Record 46 of Set 8| mehamn
# Processing Record 47 of Set 8| zaigrayevo
# Processing Record 48 of Set 8| alice springs
# Processing Record 49 of Set 8| teguise
# Processing Record 50 of Set 8| samaipata
# Processing Record 1 of Set 9| lebork
# Processing Record 2 of Set 9| bengkalis
# City not found. Skipping...
# Processing Record 3 of Set 9| camacha
# Processing Record 4 of Set 9| hun
# Processing Record 5 of Set 9| tura
# Processing Record 6 of Set 9| magadan
# Processing Record 7 of Set 9| taonan
# Processing Record 8 of Set 9| ananas
# Processing Record 9 of Set 9| gillette
# Processing Record 10 of Set 9| buta
# Processing Record 11 of Set 9| slave lake
# Processing Record 12 of Set 9| yarmouth
# Processing Record 13 of Set 9| tamandare
# Processing Record 14 of Set 9| curvelo
# Processing Record 15 of Set 9| baghdad
# Processing Record 16 of Set 9| celestun
# Processing Record 17 of Set 9| chuy
# Processing Record 18 of Set 9| morondava
# Processing Record 19 of Set 9| viedma
# Processing Record 20 of Set 9| obluche
# City not found. Skipping...
# Processing Record 21 of Set 9| namibe
# Processing Record 22 of Set 9| arsenyev
# Processing Record 23 of Set 9| keningau
# Processing Record 24 of Set 9| westpunt
# City not found. Skipping...
# Processing Record 25 of Set 9| reconquista
# Processing Record 26 of Set 9| jian
# Processing Record 27 of Set 9| nakasongola
# Processing Record 28 of Set 9| gouyave
# Processing Record 29 of Set 9| beaupre
# Processing Record 30 of Set 9| kemijarvi
# Processing Record 31 of Set 9| tulun
# Processing Record 32 of Set 9| khorixas
# Processing Record 33 of Set 9| kargil
# Processing Record 34 of Set 9| mrirt
# City not found. Skipping...
# Processing Record 35 of Set 9| hegang
# Processing Record 36 of Set 9| imbituba
# Processing Record 37 of Set 9| maraa
# Processing Record 38 of Set 9| lagoa
# Processing Record 39 of Set 9| birjand
# Processing Record 40 of Set 9| cayenne
# Processing Record 41 of Set 9| mirabad
# Processing Record 42 of Set 9| vangaindrano
# Processing Record 43 of Set 9| beloha
# Processing Record 44 of Set 9| sadiqabad
# Processing Record 45 of Set 9| scarborough
# Processing Record 46 of Set 9| san pedro
# Processing Record 47 of Set 9| tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 9| sechura
# Processing Record 49 of Set 9| lithakia
# Processing Record 50 of Set 9| santiago del estero
# Processing Record 1 of Set 10| deputatskiy
# Processing Record 2 of Set 10| la ronge
# Processing Record 3 of Set 10| ghanzi
# Processing Record 4 of Set 10| vaitape
# Processing Record 5 of Set 10| itambacuri
# Processing Record 6 of Set 10| yarada
# Processing Record 7 of Set 10| taoudenni
# Processing Record 8 of Set 10| mount pleasant
# Processing Record 9 of Set 10| husavik
# Processing Record 10 of Set 10| palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 10| lavos
# Processing Record 12 of Set 10| porto santo
# Processing Record 13 of Set 10| bac can
# City not found. Skipping...
# Processing Record 14 of Set 10| voznesenskoye
# Processing Record 15 of Set 10| sal rei
# Processing Record 16 of Set 10| kargasok
# Processing Record 17 of Set 10| shelburne
# Processing Record 18 of Set 10| muros
# Processing Record 19 of Set 10| dunedin
# Processing Record 20 of Set 10| purpe
# Processing Record 21 of Set 10| chaadayevka
# Processing Record 22 of Set 10| prenzlau
# Processing Record 23 of Set 10| senneterre
# Processing Record 24 of Set 10| berlevag
# Processing Record 25 of Set 10| westport
# Processing Record 26 of Set 10| ust-tsilma
# Processing Record 27 of Set 10| amboasary
# Processing Record 28 of Set 10| fivizzano
# Processing Record 29 of Set 10| chinna salem
# Processing Record 30 of Set 10| acapulco
# Processing Record 31 of Set 10| vestmannaeyjar
# Processing Record 32 of Set 10| abaza
# Processing Record 33 of Set 10| marsa matruh
# Processing Record 34 of Set 10| romitan
# Processing Record 35 of Set 10| san cristobal
# Processing Record 36 of Set 10| nadym
# Processing Record 37 of Set 10| yomitan
# City not found. Skipping...
# Processing Record 38 of Set 10| hazorasp
# Processing Record 39 of Set 10| porto walter
# Processing Record 40 of Set 10| kalmunai
# Processing Record 41 of Set 10| galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 10| kokopo
# Processing Record 43 of Set 10| esperance
# Processing Record 44 of Set 10| ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 10| bolshiye uki
# City not found. Skipping...
# Processing Record 46 of Set 10| bonthe
# Processing Record 47 of Set 10| sorvag
# City not found. Skipping...
# Processing Record 48 of Set 10| iberia
# Processing Record 49 of Set 10| narsaq
# Processing Record 50 of Set 10| naze
# Processing Record 1 of Set 11| manaure
# Processing Record 2 of Set 11| utiroa
# City not found. Skipping...
# Processing Record 3 of Set 11| iralaya
# Processing Record 4 of Set 11| henties bay
# Processing Record 5 of Set 11| isangel
# Processing Record 6 of Set 11| burnie
# Processing Record 7 of Set 11| greenwood
# Processing Record 8 of Set 11| kathmandu
# Processing Record 9 of Set 11| richard toll
# City not found. Skipping...
# Processing Record 10 of Set 11| bengkulu
# Processing Record 11 of Set 11| linkoping
# Processing Record 12 of Set 11| hannibal
# Processing Record 13 of Set 11| tutoia
# Processing Record 14 of Set 11| cuichapa
# Processing Record 15 of Set 11| tianpeng
# Processing Record 16 of Set 11| arnedo
# Processing Record 17 of Set 11| guadix
# Processing Record 18 of Set 11| upington
# Processing Record 19 of Set 11| araouane
# Processing Record 20 of Set 11| pisco
# Processing Record 21 of Set 11| bridlington
# Processing Record 22 of Set 11| leghorn
# City not found. Skipping...
# Processing Record 23 of Set 11| garden city
# Processing Record 24 of Set 11| aklavik
# Processing Record 25 of Set 11| barcelos
# Processing Record 26 of Set 11| majene
# Processing Record 27 of Set 11| eskasem
# City not found. Skipping...
# Processing Record 28 of Set 11| kodinsk
# Processing Record 29 of Set 11| axim
# Processing Record 30 of Set 11| opelousas
# Processing Record 31 of Set 11| puquio
# Processing Record 32 of Set 11| ayan
# Processing Record 33 of Set 11| tamara
# Processing Record 34 of Set 11| sassandra
# Processing Record 35 of Set 11| cockburn town
# Processing Record 36 of Set 11| muzhi
# Processing Record 37 of Set 11| kokstad
# Processing Record 38 of Set 11| fairview
# Processing Record 39 of Set 11| ucluelet
# Processing Record 40 of Set 11| hambantota
# Processing Record 41 of Set 11| mildura
# Processing Record 42 of Set 11| the pas
# Processing Record 43 of Set 11| omsukchan
# Processing Record 44 of Set 11| matamoros
# Processing Record 45 of Set 11| tawnat
# City not found. Skipping...
# Processing Record 46 of Set 11| virginia beach
# Processing Record 47 of Set 11| evensk
# Processing Record 48 of Set 11| baracoa
# Processing Record 49 of Set 11| houston
# Processing Record 50 of Set 11| port augusta
# Processing Record 1 of Set 12| palasa
# Processing Record 2 of Set 12| aksu
# Processing Record 3 of Set 12| karla
# Processing Record 4 of Set 12| macheng
# Processing Record 5 of Set 12| lubaczow
# Processing Record 6 of Set 12| dergachi
# Processing Record 7 of Set 12| lithgow
# Processing Record 8 of Set 12| gao
# Processing Record 9 of Set 12| mareeba
# Processing Record 10 of Set 12| camrose
# Processing Record 11 of Set 12| tessalit
# Processing Record 12 of Set 12| jiuquan
# Processing Record 13 of Set 12| vao
# Processing Record 14 of Set 12| bargal
# City not found. Skipping...
# Processing Record 15 of Set 12| sangar
# Processing Record 16 of Set 12| sagua la grande
# Processing Record 17 of Set 12| sorong
# Processing Record 18 of Set 12| port hueneme
# Processing Record 19 of Set 12| puli
# Processing Record 20 of Set 12| kashi
# Processing Record 21 of Set 12| puerto colombia
# Processing Record 22 of Set 12| geraldton
# Processing Record 23 of Set 12| huarmey
# Processing Record 24 of Set 12| piacabucu
# Processing Record 25 of Set 12| caravelas
# Processing Record 26 of Set 12| korla
# Processing Record 27 of Set 12| basoko
# Processing Record 28 of Set 12| pierre
# Processing Record 29 of Set 12| ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 12| inhambane
# Processing Record 31 of Set 12| ngemplak
# Processing Record 32 of Set 12| kuminskiy
# Processing Record 33 of Set 12| champoton
# Processing Record 34 of Set 12| nancha
# Processing Record 35 of Set 12| singapore
# Processing Record 36 of Set 12| vestmanna
# Processing Record 37 of Set 12| foam lake
# Processing Record 38 of Set 12| panara
# Processing Record 39 of Set 12| khartoum
# Processing Record 40 of Set 12| dakar
# Processing Record 41 of Set 12| suntar
# Processing Record 42 of Set 12| verkh-usugli
# Processing Record 43 of Set 12| marawi
# Processing Record 44 of Set 12| aberdeen
# Processing Record 45 of Set 12| jabiru
# City not found. Skipping...
# Processing Record 46 of Set 12| aberdare
# Processing Record 47 of Set 12| balaka
# Processing Record 48 of Set 12| agadez
# Processing Record 49 of Set 12| coruripe
# Processing Record 50 of Set 12| nikolaevo
# Processing Record 1 of Set 13| abha
# Processing Record 2 of Set 13| crestview
# Processing Record 3 of Set 13| wuning
# Processing Record 4 of Set 13| cidreira
# Processing Record 5 of Set 13| turukhansk
# Processing Record 6 of Set 13| kismayo
# Processing Record 7 of Set 13| shyryayeve
# Processing Record 8 of Set 13| bodden town
# Processing Record 9 of Set 13| nioro
# Processing Record 10 of Set 13| sao gabriel da cachoeira
# Processing Record 11 of Set 13| sioux lookout
# Processing Record 12 of Set 13| halalo
# City not found. Skipping...
# Processing Record 13 of Set 13| tunduru
# City not found. Skipping...
# Processing Record 14 of Set 13| zaysan
# Processing Record 15 of Set 13| sao miguel do araguaia
# Processing Record 16 of Set 13| khani
# Processing Record 17 of Set 13| troitskoye
# Processing Record 18 of Set 13| haines junction
# Processing Record 19 of Set 13| ranau
# Processing Record 20 of Set 13| richards bay
# Processing Record 21 of Set 13| karsun
# Processing Record 22 of Set 13| jalu
# Processing Record 23 of Set 13| pafos
# Processing Record 24 of Set 13| borama
# City not found. Skipping...
# Processing Record 25 of Set 13| kloulklubed
# Processing Record 26 of Set 13| udachnyy
# Processing Record 27 of Set 13| gangotri
# City not found. Skipping...
# Processing Record 28 of Set 13| casa nova
# Processing Record 29 of Set 13| morro bay
# Processing Record 30 of Set 13| pulaski
# Processing Record 31 of Set 13| quatre cocos
# Processing Record 32 of Set 13| floro
# Processing Record 33 of Set 13| vylgort
# City not found. Skipping...
# Processing Record 34 of Set 13| kawana waters
# City not found. Skipping...
# Processing Record 35 of Set 13| gulf gate estates
# Processing Record 36 of Set 13| gizeh
# Processing Record 37 of Set 13| petauke
# Processing Record 38 of Set 13| sturgeon falls
# Processing Record 39 of Set 13| saint-pierre
# Processing Record 40 of Set 13| hovd
# Processing Record 41 of Set 13| zhezkazgan
# Processing Record 42 of Set 13| pamplona
# Processing Record 43 of Set 13| riohacha
# Processing Record 44 of Set 13| nelson bay
# Processing Record 45 of Set 13| hervey bay
# Processing Record 46 of Set 13| lanigan
# Processing Record 47 of Set 13| xinzhi
# Processing Record 48 of Set 13| chemin grenier
# Processing Record 49 of Set 13| terrace
# Processing Record 50 of Set 13| bani
# Processing Record 1 of Set 14| dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 14| petropavlovsk-kamchatskiy
# Processing Record 3 of Set 14| aksarka
# Processing Record 4 of Set 14| beba
# Processing Record 5 of Set 14| namatanai
# Processing Record 6 of Set 14| kemi
# Processing Record 7 of Set 14| shingu
# Processing Record 8 of Set 14| shunyi
# Processing Record 9 of Set 14| tingi
# Processing Record 10 of Set 14| two hills
# Processing Record 11 of Set 14| monrovia
# Processing Record 12 of Set 14| astana
# Processing Record 13 of Set 14| qui nhon
# Processing Record 14 of Set 14| rincon
# Processing Record 15 of Set 14| kalaiya
# Processing Record 16 of Set 14| isilkul
# Processing Record 17 of Set 14| hofn
# Processing Record 18 of Set 14| cobija
# Processing Record 19 of Set 14| khilok
# Processing Record 20 of Set 14| novikovo
# Processing Record 21 of Set 14| laiagam
# City not found. Skipping...
# Processing Record 22 of Set 14| mnogovershinnyy
# Processing Record 23 of Set 14| yeppoon
# Processing Record 24 of Set 14| morant bay
# Processing Record 25 of Set 14| bubaque
# Processing Record 26 of Set 14| montepuez
# Processing Record 27 of Set 14| balkanabat
# Processing Record 28 of Set 14| tahara
# Processing Record 29 of Set 14| kutum
# Processing Record 30 of Set 14| toronto
# Processing Record 31 of Set 14| kavaratti
# Processing Record 32 of Set 14| lugovoy
# Processing Record 33 of Set 14| lucea
# Processing Record 34 of Set 14| pacific grove
# Processing Record 35 of Set 14| saint austell
# Processing Record 36 of Set 14| natal
# Processing Record 37 of Set 14| samana
# Processing Record 38 of Set 14| tarudant
# City not found. Skipping...
# Processing Record 39 of Set 14| anadyr
# Processing Record 40 of Set 14| vitim
# Processing Record 41 of Set 14| qom
# Processing Record 42 of Set 14| burriana
# Processing Record 43 of Set 14| saeby
# Processing Record 44 of Set 14| bukachacha
# Processing Record 45 of Set 14| parfino
# Processing Record 46 of Set 14| jiaocheng
# Processing Record 47 of Set 14| buenos aires
# Processing Record 48 of Set 14| eyl
# Processing Record 49 of Set 14| chabahar
# Processing Record 50 of Set 14| nyimba
# Processing Record 1 of Set 15| esna
# Processing Record 2 of Set 15| zhenhai
# Processing Record 3 of Set 15| altay
# Processing Record 4 of Set 15| ust-maya
# Processing Record 5 of Set 15| kalabo
# Processing Record 6 of Set 15| kita
# Processing Record 7 of Set 15| dembi dolo
# Processing Record 8 of Set 15| sakakah
# Processing Record 9 of Set 15| ilovlya
# Processing Record 10 of Set 15| talpa
# Processing Record 11 of Set 15| calvinia
# Processing Record 12 of Set 15| praia da vitoria
# Processing Record 13 of Set 15| am timan
# Processing Record 14 of Set 15| chapais
# Processing Record 15 of Set 15| les cayes
# Processing Record 16 of Set 15| mancio lima
# Processing Record 17 of Set 15| dongsheng
# Processing Record 18 of Set 15| remontnoye
# Processing Record 19 of Set 15| charlestown
# Processing Record 20 of Set 15| moree
# Processing Record 21 of Set 15| barra patuca
# Processing Record 22 of Set 15| onguday
# Processing Record 23 of Set 15| taihe
# Processing Record 24 of Set 15| blind river
# Processing Record 25 of Set 15| samfya
# Processing Record 26 of Set 15| marolambo
# Processing Record 27 of Set 15| mollendo
# Processing Record 28 of Set 15| gunjur
# Processing Record 29 of Set 15| beihai
# Processing Record 30 of Set 15| arman
# Processing Record 31 of Set 15| buqayq
# City not found. Skipping...
# Processing Record 32 of Set 15| sinazongwe
# Processing Record 33 of Set 15| kotaparh
# Processing Record 34 of Set 15| varhaug
# Processing Record 35 of Set 15| rocha
# Processing Record 36 of Set 15| pascagoula
# Processing Record 37 of Set 15| ayame
# Processing Record 38 of Set 15| palmer
# Processing Record 39 of Set 15| yuli
# Processing Record 40 of Set 15| lanzhou
# Processing Record 41 of Set 15| jagtial
# Processing Record 42 of Set 15| rio cauto
# Processing Record 43 of Set 15| urumqi
# Processing Record 44 of Set 15| camana
# Processing Record 45 of Set 15| tromso
# Processing Record 46 of Set 15| pinega
# Processing Record 47 of Set 15| predivinsk
# Processing Record 48 of Set 15| ulaanbaatar
# Processing Record 49 of Set 15| gallup
# Processing Record 50 of Set 15| at-bashi
# Processing Record 1 of Set 16| deep river
# Processing Record 2 of Set 16| tome-acu
# City not found. Skipping...
# Processing Record 3 of Set 16| ha giang
# Processing Record 4 of Set 16| pangody
# Processing Record 5 of Set 16| san rafael
# Processing Record 6 of Set 16| bad hofgastein
# Processing Record 7 of Set 16| phalaborwa
# Processing Record 8 of Set 16| bangalore
# Processing Record 9 of Set 16| havoysund
# Processing Record 10 of Set 16| caraballeda
# Processing Record 11 of Set 16| itarema
# Processing Record 12 of Set 16| seybaplaya
# Processing Record 13 of Set 16| mount gambier
# Processing Record 14 of Set 16| anzhero-sudzhensk
# Processing Record 15 of Set 16| el dorado
# Processing Record 16 of Set 16| harindanga
# Processing Record 17 of Set 16| ust-ilimsk
# Processing Record 18 of Set 16| port hardy
# Processing Record 19 of Set 16| nakusp
# Processing Record 20 of Set 16| tres arroyos
# Processing Record 21 of Set 16| champerico
# Processing Record 22 of Set 16| porto novo
# Processing Record 23 of Set 16| gamba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Codrington -38.2667  141.9667     80.55        25          61
# 1       Provideniya  64.3833 -173.3000     -7.49        71           0
# 2          Tasiilaq  65.6145  -37.6368     41.16        77         100
# 3    Ribeira Grande  38.5167  -28.7000     58.71        53         100
# 4             Alofi -19.0595 -169.9187     78.21        70           8
# ..              ...      ...       ...       ...       ...         ...
# 702          Nakusp  50.2499 -117.8023     37.74        75          99
# 703    Tres Arroyos -38.3739  -60.2798     75.67        25          25
# 704      Champerico  14.3000  -91.9167     88.34        68           1
# 705      Porto Novo   6.4965    2.6036     84.02        80          34
# 706           Gamba  -2.6500   10.0000     75.52        94         100
#
#      Wind Speed Country
# 0         17.02      AU
# 1          6.71      RU
# 2         18.90      GL
# 3         21.34      PT
# 4          6.96      NU
# ..          ...     ...
# 702        1.14      CA
# 703        7.74      AR
# 704        8.01      GT
# 705        7.81      BJ
# 706        2.64      GA
#
# [707 rows x 8 columns]
